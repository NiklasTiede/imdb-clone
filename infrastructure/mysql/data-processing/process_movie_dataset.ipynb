# %%
# process original IMDb Dataset

# %%
import pandas as pd
import numpy as np
from utilities import convert_str_to_bitvalue, convert_tconst_to_indexnum, convert_enum_to_number

# %%
df = pd.read_csv("imdb-dataset/movies.tsv", sep='\t')

# %%
# correct runtimeMinutes / isAdult column: they contains faulty values
df.loc[df['runtimeMinutes'].astype(str).str.contains('[^0-9]+') & (df['runtimeMinutes'].astype(str).str.len() > 3), 'runtimeMinutes'] = '\\N'
df.loc[~df['isAdult'].isin([0, 1, '0', '1', '\\N']), 'isAdult'] = '\\N'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'runtimeMinutes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 # correct runtimeMinutes / isAdult column: they contains faulty values
# ----> 2 df.loc[df['runtimeMinutes'].astype(str).str.contains('[^0-9]+') & (df['runtimeMinutes'].astype(str).str.len() > 3), 'runtimeMinutes'] = '\\N'
#       3 df.loc[~df['isAdult'].isin([0, 1, '0', '1', '\\N']), 'isAdult'] = '\\N'
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:3760, in DataFrame.__getitem__(self, key)
#    3758 if self.columns.nlevels > 1:
#    3759     return self._getitem_multilevel(key)
# -> 3760 indexer = self.columns.get_loc(key)
#    3761 if is_integer(indexer):
#    3762     indexer = [indexer]
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'runtimeMinutes'

# %%
df
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1965
# 1        tt0000002            5.8       263
# 2        tt0000003            6.5      1807
# 3        tt0000004            5.6       178
# 4        tt0000005            6.2      2604
# ...            ...            ...       ...
# 1301737  tt9916730            8.3        10
# 1301738  tt9916766            7.0        21
# 1301739  tt9916778            7.2        36
# 1301740  tt9916840            8.8         6
# 1301741  tt9916880            8.2         6
#
# [1301742 rows x 3 columns]

# %%
df['titleType'] = df['titleType'].map(lambda a: convert_enum_to_number(a))

# %%
df['tconst'] = df['tconst'].map(lambda a: convert_tconst_to_indexnum(a))

# %%
# calculation takes about 3 min
df['genres'] = df['genres'].map(lambda a: convert_str_to_bitvalue(a))

# %%
df.set_index('tconst', inplace=True)

# %%
df_ratings = pd.read_csv("imdb-dataset/ratings.tsv", sep='\t')

# %%
df_ratings['tconst'] = df_ratings['tconst'].map(lambda a: convert_tconst_to_indexnum(a))

# %%
df_ratings.set_index('tconst', inplace=True)

# %%
result_df = df.join(df_ratings)

# %%
result_df['averageRating'] = result_df['averageRating'].replace(np.NaN, "\\N")

# %%
result_df['numVotes'] = result_df['numVotes'].replace(np.NaN, "\\N")

# %%
result_df['genres'] = pd.to_numeric(result_df['genres'], errors='coerce')
result_df['genres'] = result_df['genres'].replace(np.NaN, "\\N")

# %%
result_df.index.names = ['id']

# %%
mapping = {
    "titleType":"movie_type",
    "primaryTitle":"primary_title", 
    "originalTitle":"original_title", 
    "isAdult":"adult", 
    "startYear":"start_year", 
    "endYear":"end_year", 
    "runtimeMinutes":"runtime_minutes", 
    "genres":"movie_genre",
    "averageRating":"imdb_rating",
    "numVotes":"imdb_rating_count",
}

# %%
result_df = result_df.rename(columns=mapping)

# %%
# merge description / url token dataset into this one
result_df = pd.read_csv("processed_imdb_movies.csv")
result_df.set_index('id', inplace=True)
# Out:
# /home/niklas/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: DtypeWarning: Columns (1,4,5,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_image_description = pd.read_csv("imdb-dataset/movies_image_url_description.csv")

# %%
df_image_description = df_image_description.drop('poster_path', axis=1)
df_image_description = df_image_description.drop('primaryTitle', axis=1)
df_image_description = df_image_description.drop('imdbId', axis=1)

# %%
df_image_description.rename(columns={'overview': 'description', 'url_token': 'image_url_token'}, inplace=True)

# %%
df_image_description.set_index('id', inplace=True)

# %%
# cut_df = df_image_description.loc[:9700940]
cut_df = df_image_description.loc[:9018776]

# %%
end_df = result_df.join(cut_df)

# %%
end_df['description'].replace(np.NaN, "\\N", inplace=True)
end_df['image_url_token'].replace(np.NaN, "\\N", inplace=True)

# %%
end_df
# Out:
#         movie_type              primary_title             original_title  \
# id
# 1                0                 Carmencita                 Carmencita
# 2                0     Le clown et ses chiens     Le clown et ses chiens
# 3                0             Pauvre Pierrot             Pauvre Pierrot
# 4                0                Un bon bock                Un bon bock
# 5                0           Blacksmith Scene           Blacksmith Scene
# ...            ...                        ...                        ...
# 9916848          4              Episode #3.17              Episode #3.17
# 9916850          4              Episode #3.19              Episode #3.19
# 9916852          4              Episode #3.20              Episode #3.20
# 9916856          0                   The Wind                   The Wind
# 9916880          4  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#         adult start_year end_year runtime_minutes  movie_genre imdb_rating  \
# id
# 1           0       1894       \N               1  270532609.0         5.7
# 2           0       1892       \N               5  268437505.0         5.9
# 3           0       1892       \N               4      35841.0         6.5
# 4           0       1892       \N              12  268437505.0         5.7
# 5           0       1893       \N               1  268436481.0         6.2
# ...       ...        ...      ...             ...          ...         ...
# 9916848     0       2010       \N              \N      17025.0          \N
# 9916850     0       2010       \N              \N      17025.0          \N
# 9916852     0       2010       \N              \N      17025.0          \N
# 9916856     0       2015       \N              27  268435457.0          \N
# 9916880     0       2014       \N              10       3329.0          \N
#
#         imdb_rating_count description image_url_token
# id
# 1                  1892.0          \N              \N
# 2                   252.0          \N              \N
# 3                  1685.0          \N              \N
# 4                   165.0          \N              \N
# 5                  2499.0          \N              \N
# ...                   ...         ...             ...
# 9916848                \N          \N              \N
# 9916850                \N          \N              \N
# 9916852                \N          \N              \N
# 9916856                \N          \N              \N
# 9916880                \N          \N              \N
#
# [9018777 rows x 12 columns]

# %%
end_df.to_csv('processed_imdb_movies_end.csv')

# %%
end_df
# Out:
#          movie_type              primary_title             original_title  \
# id
# 1                 0                 Carmencita                 Carmencita
# 2                 0     Le clown et ses chiens     Le clown et ses chiens
# 3                 0             Pauvre Pierrot             Pauvre Pierrot
# 4                 0                Un bon bock                Un bon bock
# 5                 0           Blacksmith Scene           Blacksmith Scene
# ...             ...                        ...                        ...
# 9916848           4              Episode #3.17              Episode #3.17
# 9916850           4              Episode #3.19              Episode #3.19
# 9916852           4              Episode #3.20              Episode #3.20
# 9916856           0                   The Wind                   The Wind
# 9916880           4  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#         adult start_year end_year runtime_minutes  movie_genre imdb_rating  \
# id
# 1           0       1894       \N               1  270532609.0         5.7
# 2           0       1892       \N               5  268437505.0         5.8
# 3           0       1892       \N               4      35841.0         6.5
# 4           0       1892       \N              12  268437505.0         5.6
# 5           0       1893       \N               1  268436481.0         6.2
# ...       ...        ...      ...             ...          ...         ...
# 9916848     0       2010       \N              \N      17025.0          \N
# 9916850     0       2010       \N              \N      17025.0          \N
# 9916852     0       2010       \N              \N      17025.0          \N
# 9916856     0       2015       \N              27  268435457.0          \N
# 9916880     0       2014       \N              10       3329.0         8.2
#
#         imdb_rating_count description image_url_token
# id
# 1                  1959.0          \N              \N
# 2                   263.0          \N              \N
# 3                  1799.0          \N              \N
# 4                   179.0          \N              \N
# 5                  2596.0          \N              \N
# ...                   ...         ...             ...
# 9916848                \N          \N              \N
# 9916850                \N          \N              \N
# 9916852                \N          \N              \N
# 9916856                \N          \N              \N
# 9916880               6.0          \N              \N
#
# [9700941 rows x 12 columns]

# %%
# Out:
# id
# 1          270532609.0
# 2          268437505.0
# 3              35841.0
# 4          268437505.0
# 5          268436481.0
#               ...
# 9916848        17025.0
# 9916850        17025.0
# 9916852        17025.0
# 9916856    268435457.0
# 9916880         3329.0
# Name: movie_genre, Length: 9700941, dtype: float64

# %%
# Convert column 'col1' of DataFrame 'df' to strings and filter rows with length less than 2
end_df['movie_genre'] = end_df['movie_genre'].astype(str)
df_filtered = end_df[~end_df['movie_genre'].str.contains(r'^\\N$') & (end_df['movie_genre'].str.len() <= 2)]

# %%
df_filtered
# Out:
# Empty DataFrame
# Columns: [movie_type, primary_title, original_title, adult, start_year, end_year, runtime_minutes, movie_genre, imdb_rating, imdb_rating_count, description, image_url_token]
# Index: []

# %%
new_df = end_df.drop('description', axis=1)
new_df = new_df.drop('image_url_token', axis=1)

# %%
end_df
# Out:
#          movie_type              primary_title             original_title  \
# id
# 1                 0                 Carmencita                 Carmencita
# 2                 0     Le clown et ses chiens     Le clown et ses chiens
# 3                 0             Pauvre Pierrot             Pauvre Pierrot
# 4                 0                Un bon bock                Un bon bock
# 5                 0           Blacksmith Scene           Blacksmith Scene
# ...             ...                        ...                        ...
# 9916848           4              Episode #3.17              Episode #3.17
# 9916850           4              Episode #3.19              Episode #3.19
# 9916852           4              Episode #3.20              Episode #3.20
# 9916856           0                   The Wind                   The Wind
# 9916880           4  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#         adult start_year end_year runtime_minutes  movie_genre imdb_rating  \
# id
# 1           0       1894       \N               1  270532609.0         5.7
# 2           0       1892       \N               5  268437505.0         5.8
# 3           0       1892       \N               4      35841.0         6.5
# 4           0       1892       \N              12  268437505.0         5.6
# 5           0       1893       \N               1  268436481.0         6.2
# ...       ...        ...      ...             ...          ...         ...
# 9916848     0       2010       \N              \N      17025.0          \N
# 9916850     0       2010       \N              \N      17025.0          \N
# 9916852     0       2010       \N              \N      17025.0          \N
# 9916856     0       2015       \N              27  268435457.0          \N
# 9916880     0       2014       \N              10       3329.0         8.2
#
#         imdb_rating_count description image_url_token
# id
# 1                  1959.0          \N              \N
# 2                   263.0          \N              \N
# 3                  1799.0          \N              \N
# 4                   179.0          \N              \N
# 5                  2596.0          \N              \N
# ...                   ...         ...             ...
# 9916848                \N          \N              \N
# 9916850                \N          \N              \N
# 9916852                \N          \N              \N
# 9916856                \N          \N              \N
# 9916880               6.0          \N              \N
#
# [9700941 rows x 12 columns]

# %%
mini_df
# Out:
#     movie_type           primary_title          original_title adult  \
# id
# 1            0              Carmencita              Carmencita     0
# 2            0  Le clown et ses chiens  Le clown et ses chiens     0
# 3            0          Pauvre Pierrot          Pauvre Pierrot     0
# 4            0             Un bon bock             Un bon bock     0
# 5            0        Blacksmith Scene        Blacksmith Scene     0
#
#    start_year end_year runtime_minutes  movie_genre imdb_rating  \
# id
# 1        1894       \N               1  270532609.0         5.7
# 2        1892       \N               5  268437505.0         5.8
# 3        1892       \N               4      35841.0         6.5
# 4        1892       \N              12  268437505.0         5.6
# 5        1893       \N               1  268436481.0         6.2
#
#    imdb_rating_count description image_url_token
# id
# 1             1959.0          \N              \N
# 2              263.0          \N              \N
# 3             1799.0          \N              \N
# 4              179.0          \N              \N
# 5             2596.0          \N              \N

# %%
new_df.to_csv('processed_imdb_movies.csv')

# %%
result_df
# Out:
#         movie_type              primary_title             original_title  \
# id
# 1                0                 Carmencita                 Carmencita
# 2                0     Le clown et ses chiens     Le clown et ses chiens
# 3                0             Pauvre Pierrot             Pauvre Pierrot
# 4                0                Un bon bock                Un bon bock
# 5                0           Blacksmith Scene           Blacksmith Scene
# ...            ...                        ...                        ...
# 9916848          4              Episode #3.17              Episode #3.17
# 9916850          4              Episode #3.19              Episode #3.19
# 9916852          4              Episode #3.20              Episode #3.20
# 9916856          0                   The Wind                   The Wind
# 9916880          4  Horrid Henry Knows It All  Horrid Henry Knows It All
#
#         adult start_year end_year runtime_minutes  movie_genre imdb_rating  \
# id
# 1           0       1894       \N               1  270532609.0         5.7
# 2           0       1892       \N               5  268437505.0         5.9
# 3           0       1892       \N               4      35841.0         6.5
# 4           0       1892       \N              12  268437505.0         5.7
# 5           0       1893       \N               1  268436481.0         6.2
# ...       ...        ...      ...             ...          ...         ...
# 9916848     0       2010       \N              \N      17025.0          \N
# 9916850     0       2010       \N              \N      17025.0          \N
# 9916852     0       2010       \N              \N      17025.0          \N
# 9916856     0       2015       \N              27  268435457.0          \N
# 9916880     0       2014       \N              10       3329.0          \N
#
#         imdb_rating_count
# id
# 1                  1892.0
# 2                   252.0
# 3                  1685.0
# 4                   165.0
# 5                  2499.0
# ...                   ...
# 9916848                \N
# 9916850                \N
# 9916852                \N
# 9916856                \N
# 9916880                \N
#
# [9018777 rows x 10 columns]

# %%
# whats was successfull: using old dataset and add image token and descriptions to it, 5k movies have url
